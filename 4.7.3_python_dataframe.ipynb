# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
from pydataset import data

# %%
#1a. Create a column named passing_english that indicates whether each student has a passing grade in reading.

# %%
df['passing_english'] = df.english >70

# %%
print(df)
# Out:
#        name  math  english  reading  passing_reading  passing_english
# 0     Sally    62       85       80             True             True
# 1      Jane    88       79       67            False             True
# 2     Suzie    94       74       95             True             True
# 3     Billy    98       96       88             True             True
# 4       Ada    77       92       98             True             True
# 5      John    79       76       93             True             True
# 6    Thomas    82       64       81             True            False
# 7     Marie    93       63       90             True            False
# 8    Albert    92       62       87             True            False
# 9   Richard    69       80       94             True             True
# 10    Isaac    92       99       93             True             True
# 11     Alan    92       62       72             True            False

# %%
# b. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values(['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_reading  passing_english
# 11     Alan    92       62       72             True            False
# 8    Albert    92       62       87             True            False
# 7     Marie    93       63       90             True            False
# 6    Thomas    82       64       81             True            False
# 4       Ada    77       92       98             True             True
# 3     Billy    98       96       88             True             True
# 10    Isaac    92       99       93             True             True
# 1      Jane    88       79       67            False             True
# 5      John    79       76       93             True             True
# 9   Richard    69       80       94             True             True
# 0     Sally    62       85       80             True             True
# 2     Suzie    94       74       95             True             True

# %%
# Sort the english grades first by passing_english and then by student name. All the students that are failing 
# english should be first, and within the students that are failing english they should be ordered alphabetically. 
# The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(['passing_english','name'])
# Out:
#        name  math  english  reading  passing_reading  passing_english
# 11     Alan    92       62       72             True            False
# 8    Albert    92       62       87             True            False
# 7     Marie    93       63       90             True            False
# 6    Thomas    82       64       81             True            False
# 4       Ada    77       92       98             True             True
# 3     Billy    98       96       88             True             True
# 10    Isaac    92       99       93             True             True
# 1      Jane    88       79       67            False             True
# 5      John    79       76       93             True             True
# 9   Richard    69       80       94             True             True
# 0     Sally    62       85       80             True             True
# 2     Suzie    94       74       95             True             True

# %%
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we 
# did in the last step.

# %%
df.sort_values(['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_reading  passing_english
# 8    Albert    92       62       87             True            False
# 11     Alan    92       62       72             True            False
# 7     Marie    93       63       90             True            False
# 6    Thomas    82       64       81             True            False
# 2     Suzie    94       74       95             True             True
# 5      John    79       76       93             True             True
# 1      Jane    88       79       67            False             True
# 9   Richard    69       80       94             True             True
# 0     Sally    62       85       80             True             True
# 4       Ada    77       92       98             True             True
# 3     Billy    98       96       88             True             True
# 10    Isaac    92       99       93             True             True

# %%
#Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the 
# average of the math, english, and reading grades.

# %%
df['overall_average'] = (df['math'] + df['english'] + df['reading'])/3
df
# Out:
#        name  math  english  reading  passing_reading  passing_english  \
# 0     Sally    62       85       80             True             True
# 1      Jane    88       79       67            False             True
# 2     Suzie    94       74       95             True             True
# 3     Billy    98       96       88             True             True
# 4       Ada    77       92       98             True             True
# 5      John    79       76       93             True             True
# 6    Thomas    82       64       81             True            False
# 7     Marie    93       63       90             True            False
# 8    Albert    92       62       87             True            False
# 9   Richard    69       80       94             True             True
# 10    Isaac    92       99       93             True             True
# 11     Alan    92       62       72             True            False
#
#     overall_average
# 0         75.666667
# ...

# %%
Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data('mpg') # data set was imported at top.

# %%
mpg #show df - 234 rows × 11 columns
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
#What are the data types of each column?
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#Rename the cty column to city.

# %%
mpg = mpg.rename(columns={'cty': 'city'})
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
#Rename the hwy column to highway.

# %%
mpg = mpg.rename(columns = {'hwy': 'highway'})
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
#Do any cars have better city mileage than highway mileage?

# %%
mpg['diff_hwy_city'] = mpg['highway'] - mpg['city']
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
mpg['city_higher'] = mpg['diff_hwy_city'] < 0
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
mpg.sort_values(by='city_higher', ascending=False)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 1           audi                   a4    1.8  1999    4    auto(l5)   f    18
# 161       subaru         forester awd    2.5  1999    4    auto(l4)   4    18
# 149       nissan               maxima    3.0  1999    6  manual(m5)   f    19
# 150       nissan               maxima    3.5  2008    6    auto(av)   f    19
# 151       nissan       pathfinder 4wd    3.3  1999    6    auto(l4)   4    14
# 152       nissan       pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 153       nissan       pathfinder 4wd    4.0  2008    6    auto(l5)   4    14
# 154       nissan       pathfinder 4wd    5.6  2008    8    auto(s5)   4    12
# 155      pontiac           grand prix    3.1  1999    6    auto(l4)   f    18
# 156      pontiac           grand prix    3.8  1999    6    auto(l4)   f    16
# 157      pontiac           grand prix    3.8  1999    6    auto(l4)   f    17
# ...

# %%
# Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by = 'diff_hwy_city', ascending = False)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 107        honda                   civic    1.8  2008    4    auto(l5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 106        honda                   civic    1.8  2008    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# ...

# %%
#Which compact class car has the lowest highway mileage? The best?

# %%
mpg[mpg['class'] == 'compact'].sort_values(by = 'highway', ascending = True )
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 220   volkswagen         jetta    2.8  1999    6    auto(l4)   f    16
# 221   volkswagen         jetta    2.8  1999    6  manual(m5)   f    17
# 212   volkswagen           gti    2.8  1999    6  manual(m5)   f    17
# 172       subaru   impreza awd    2.5  2008    4  manual(m5)   4    19
# 170       subaru   impreza awd    2.5  2008    4    auto(s4)   4    20
# 15          audi    a4 quattro    3.1  2008    6  manual(m6)   4    15
# 14          audi    a4 quattro    3.1  2008    6    auto(s6)   4    17
# 13          audi    a4 quattro    2.8  1999    6  manual(m5)   4    17
# 9           audi    a4 quattro    1.8  1999    4    auto(l5)   4    16
# 12          audi    a4 quattro    2.8  1999    6    auto(l5)   4    15
# 209   volkswagen           gti    2.0  1999    4    auto(l4)   f    19
# 215   volkswagen         jetta    2.0  1999    4    auto(l4)   f    19
# ...

# %%
mpg[mpg['class'] == 'compact'].sort_values(by = 'highway', ascending = False )
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 213   volkswagen         jetta    1.9  1999    4  manual(m5)   f    33
# 197       toyota       corolla    1.8  2008    4  manual(m5)   f    28
# 196       toyota       corolla    1.8  1999    4  manual(m5)   f    26
# 198       toyota       corolla    1.8  2008    4    auto(l4)   f    26
# 195       toyota       corolla    1.8  1999    4    auto(l4)   f    24
# 189       toyota  camry solara    2.4  2008    4  manual(m5)   f    21
# 3           audi            a4    2.0  2008    4  manual(m6)   f    20
# 190       toyota  camry solara    2.4  2008    4    auto(s5)   f    22
# 4           audi            a4    2.0  2008    4    auto(av)   f    21
# 194       toyota       corolla    1.8  1999    4    auto(l3)   f    24
# 208   volkswagen           gti    2.0  1999    4  manual(m5)   f    21
# 211   volkswagen           gti    2.0  2008    4    auto(s6)   f    22
# ...

# %%
#Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg['city'] + mpg.highway)/2
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
mpg[mpg.manufacturer == 'dodge'].sort_values(by = 'average_mileage', ascending = True).head()
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 74        dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4    11
#
#     highway fl   class  diff_hwy_city  city_higher  average_mileage
# 70       12  e  pickup              3        False             10.5
# 66       12  e  pickup              3        False             10.5
# 60       12  e     suv              3        False             10.5
# 55       12  e  pickup              3        False             10.5
# 74       15  r  pickup              4        False             13.0

# %%
mpg[mpg.manufacturer == 'dodge'].sort_values(by = 'average_mileage', ascending = False).head()
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17       24
# 47        dodge  caravan 2wd    3.8  2008    6  auto(l6)   f    16       23
#
#    fl    class  diff_hwy_city  city_higher  average_mileage
# 38  r  minivan              6        False             21.0
# 42  r  minivan              7        False             20.5
# 43  r  minivan              7        False             20.5
# 39  r  minivan              7        False             20.5
# 47  r  minivan              7        False             19.5

# %%
mammals = data('Mammals')

# %%
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
# weight      107 non-null float64
# speed       107 non-null float64
# hoppers     107 non-null bool
# specials    107 non-null bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
mammals.shape
# Out:
# (107, 4)

# %%
#What is the the weight of the fastest animal?

# %%
mammals[['weight', 'speed']].sort_values(by = 'speed', ascending = False).head(1)
# Out:
#     weight  speed
# 53    55.0  110.0

# %%
#What is the overall percentage of specials?

# %%
sum(mammals.specials == True)/len(mammals)*100
# Out:
# 9.345794392523365

# %%
num_hoppers = sum((mammals.hoppers == True) & (mammals.speed > mammals.speed.median()))
print(num_hoppers)
print(num_hoppers/len(mammals.hoppers))
#print(round(num_animals/len(mammals*100),2))
# Out:
# 7
# 0.06542056074766354
